# %%
# %sql
create catalog if not exists retail_lakehouse;

use catalog retail_lakehouse;

create schema if not exists raw_landing;
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;
create schema if not exists quarantine;

create volume if not exists raw_landing.pos_sales;
create volume if not exists raw_landing.returns;
create volume if not exists raw_landing.inventory;
create volume if not exists raw_landing.reference;
create volume if not exists raw_landing.checkpoints;

describe volume raw_landing.pos_sales;
